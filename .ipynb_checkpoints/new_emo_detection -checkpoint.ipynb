# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "train"
test_dir = "test"
selected_classes = ["angry","happy","sad","neutral"]

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode="nearest"
)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48,48),
    color_mode="grayscale",
    batch_size=64,
    class_mode="categorical",
    classes=selected_classes,
    subset="training"
)
val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    color_mode="grayscale",
    batch_size=64,
    class_mode="categorical",
    classes=selected_classes,
    subset="validation"
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    color_mode="grayscale",
    batch_size=64,
    class_mode="categorical",
    classes=selected_classes
)
# Out:
# Found 16804 images belonging to 4 classes.
# Found 4201 images belonging to 4 classes.
# Found 5212 images belonging to 4 classes.

# %%
import os
selected_classes=["angry","happy","sad","neutral"]
for emotion in selected_classes:
    count = len(os.listdir(os.path.join(train_dir, emotion)))
    print(f"{emotion}: {count} images")
# Out:
# angry: 3995 images
# happy: 7215 images
# sad: 4830 images
# neutral: 4965 images

# %%
import matplotlib.pyplot as plt
import random

plt.figure(figsize=(12,8))

for i, emotion in enumerate(selected_classes):
    img_path = os.path.join(train_dir, emotion, random.choice(os.listdir(os.path.join(train_dir, emotion))))
    img = plt.imread(img_path)

    plt.subplot(2,2,i+1)
    plt.imshow(img, cmap="gray")
    plt.title(emotion)
    plt.axis("off")

plt.show()

# %%
img.shape
# Out:
# (48, 48)

# %%
plt.hist(img.flatten(), bins=50)
plt.title("Pixel Value Distribution")
plt.show()

# %%
train_generator.class_indices
# Out:
# {'angry': 0, 'happy': 1, 'sad': 2, 'neutral': 3}

# %%
import numpy as np
from collections import Counter

labels = train_generator.classes
Counter(labels)
# Out:
# Counter({1: 5772, 3: 3972, 2: 3864, 0: 3196})

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# {0: 1.3144555694618272,
#  1: 0.7278239778239778,
#  2: 1.0872153209109732,
#  3: 1.0576535750251763}

# %%
import tensorflow as tf

from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Dense, Flatten
from tensorflow.keras.models import Sequential

# Block 1
model = Sequential([tf.keras.Input(shape=(48,48,1))])
model.add(Conv2D(64,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Block 2
model.add(Conv2D(128,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Block 3
model.add(Conv2D(256,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Block 3
model.add(Conv2D(512,(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(256,activation='relu') )
model.add(Dropout(0.5) )
model.add(Dense(4, activation='softmax'))

model.summary()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy']
)
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_37 (Conv2D)              │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_33 (Dropout)            │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_28 (MaxPooling2D) │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_34 (Dropout)            │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_29 (MaxPooling2D) │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_35 (Dropout)            │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_30          │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_30 (MaxPooling2D) │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_36 (Dropout)            │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_37 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,734,596 (10.43 MB)
#  Trainable params: 2,732,676 (10.42 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_emotion_model.h5",
    monitor='val_accuracy',
    save_best_only=True
)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    class_weight=class_weights,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2590 - loss: 7.7417
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 18s 64ms/step - accuracy: 0.2648 - loss: 8.0471 - val_accuracy: 0.3433 - val_loss: 2.1869
# Epoch 2/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2680 - loss: 7.9886
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 16s 62ms/step - accuracy: 0.2744 - loss: 7.7723 - val_accuracy: 0.3673 - val_loss: 1.9926
# Epoch 3/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2771 - loss: 6.6056
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 17s 64ms/step - accuracy: 0.2838 - loss: 6.1762 - val_accuracy: 0.3680 - val_loss: 1.6392
# Epoch 4/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2842 - loss: 5.0564
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 17s 64ms/step - accuracy: 0.2826 - loss: 4.5821 - val_accuracy: 0.3932 - val_loss: 1.4154
# Epoch 5/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2906 - loss: 3.3322
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - accuracy: 0.3015 - loss: 2.9555 - val_accuracy: 0.4206 - val_loss: 1.3308
# Epoch 6/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3179 - loss: 1.9890
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 18s 69ms/step - accuracy: 0.3197 - loss: 1.8082 - val_accuracy: 0.4382 - val_loss: 1.2474
# Epoch 7/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3482 - loss: 1.4405
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 21s 78ms/step - accuracy: 0.3650 - loss: 1.3921 - val_accuracy: 0.4408 - val_loss: 1.2550
# Epoch 8/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4021 - loss: 1.3158
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 22s 83ms/step - accuracy: 0.4059 - loss: 1.3130 - val_accuracy: 0.4792 - val_loss: 1.1713
# Epoch 9/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 22s 84ms/step - accuracy: 0.4294 - loss: 1.2711 - val_accuracy: 0.4663 - val_loss: 1.1926
# Epoch 10/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.4497 - loss: 1.2394 - val_accuracy: 0.4175 - val_loss: 1.2410
# Epoch 11/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4623 - loss: 1.2269
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.4755 - loss: 1.2078 - val_accuracy: 0.5187 - val_loss: 1.0947
# Epoch 12/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4907 - loss: 1.1803
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.4924 - loss: 1.1783 - val_accuracy: 0.5318 - val_loss: 1.0585
# Epoch 13/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5071 - loss: 1.1435
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.5093 - loss: 1.1390 - val_accuracy: 0.5465 - val_loss: 1.0685
# Epoch 14/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.5258 - loss: 1.1181 - val_accuracy: 0.4573 - val_loss: 1.2008
# Epoch 15/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5443 - loss: 1.0894
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.5475 - loss: 1.0832 - val_accuracy: 0.5611 - val_loss: 0.9955
# Epoch 16/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5519 - loss: 1.0770
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.5579 - loss: 1.0708 - val_accuracy: 0.5906 - val_loss: 0.9676
# Epoch 17/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5712 - loss: 1.0379
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.5681 - loss: 1.0463 - val_accuracy: 0.5939 - val_loss: 0.9415
# Epoch 18/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5779 - loss: 1.0363
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.5762 - loss: 1.0342 - val_accuracy: 0.6008 - val_loss: 0.9261
# Epoch 19/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 89ms/step - accuracy: 0.5856 - loss: 1.0142 - val_accuracy: 0.5960 - val_loss: 0.9364
# Epoch 20/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5997 - loss: 0.9994
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.5946 - loss: 1.0085 - val_accuracy: 0.6132 - val_loss: 0.9347
# Epoch 21/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.6066 - loss: 0.9838 - val_accuracy: 0.5696 - val_loss: 1.0176
# Epoch 22/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - accuracy: 0.6087 - loss: 0.9777 - val_accuracy: 0.6094 - val_loss: 0.9470
# Epoch 23/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - accuracy: 0.6088 - loss: 0.9838 - val_accuracy: 0.5639 - val_loss: 1.0367
# Epoch 24/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6130 - loss: 0.9574
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - accuracy: 0.6117 - loss: 0.9618 - val_accuracy: 0.6448 - val_loss: 0.8593
# Epoch 25/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.6225 - loss: 0.9592 - val_accuracy: 0.6089 - val_loss: 0.9824
# Epoch 26/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6185 - loss: 0.9495
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.6197 - loss: 0.9455 - val_accuracy: 0.6503 - val_loss: 0.8542
# Epoch 27/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.6296 - loss: 0.9487 - val_accuracy: 0.6263 - val_loss: 0.9340
# Epoch 28/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.6285 - loss: 0.9378 - val_accuracy: 0.5308 - val_loss: 1.0699
# Epoch 29/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.6323 - loss: 0.9332 - val_accuracy: 0.6391 - val_loss: 0.8826
# Epoch 30/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.6321 - loss: 0.9345 - val_accuracy: 0.6222 - val_loss: 0.9209
# Epoch 31/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.6326 - loss: 0.9331 - val_accuracy: 0.6356 - val_loss: 0.8818
# Epoch 32/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.6365 - loss: 0.9321 - val_accuracy: 0.6099 - val_loss: 0.9279
# Epoch 33/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.6438 - loss: 0.9129 - val_accuracy: 0.6498 - val_loss: 0.8644
# Epoch 34/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6432 - loss: 0.9117
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.6475 - loss: 0.9031 - val_accuracy: 0.6596 - val_loss: 0.8454
# Epoch 35/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.6543 - loss: 0.8984 - val_accuracy: 0.5763 - val_loss: 0.9829
# Epoch 36/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.6476 - loss: 0.9045 - val_accuracy: 0.6572 - val_loss: 0.8251
# Epoch 37/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6544 - loss: 0.8874
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 26s 100ms/step - accuracy: 0.6514 - loss: 0.8927 - val_accuracy: 0.6613 - val_loss: 0.8281
# Epoch 38/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 89ms/step - accuracy: 0.6534 - loss: 0.9001 - val_accuracy: 0.6008 - val_loss: 0.9696
# Epoch 39/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6555 - loss: 0.8937
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - accuracy: 0.6559 - loss: 0.8922 - val_accuracy: 0.6653 - val_loss: 0.8412
# Epoch 40/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6575 - loss: 0.8884
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.6584 - loss: 0.8820 - val_accuracy: 0.6770 - val_loss: 0.8084
# Epoch 41/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.6616 - loss: 0.8912 - val_accuracy: 0.6763 - val_loss: 0.7983
# Epoch 42/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.6604 - loss: 0.8838 - val_accuracy: 0.6437 - val_loss: 0.8464
# Epoch 43/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.6668 - loss: 0.8710 - val_accuracy: 0.6615 - val_loss: 0.8407
# Epoch 44/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 89ms/step - accuracy: 0.6645 - loss: 0.8687 - val_accuracy: 0.6770 - val_loss: 0.7894
# Epoch 45/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 89ms/step - accuracy: 0.6680 - loss: 0.8654 - val_accuracy: 0.6608 - val_loss: 0.8256
# Epoch 46/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 87ms/step - accuracy: 0.6676 - loss: 0.8696 - val_accuracy: 0.6106 - val_loss: 0.9457
# Epoch 47/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6752 - loss: 0.8549
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.6731 - loss: 0.8660 - val_accuracy: 0.6796 - val_loss: 0.7832
# Epoch 48/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6777 - loss: 0.8602
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 23s 86ms/step - accuracy: 0.6769 - loss: 0.8618 - val_accuracy: 0.6806 - val_loss: 0.8094
# Epoch 49/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 25s 95ms/step - accuracy: 0.6733 - loss: 0.8659 - val_accuracy: 0.6153 - val_loss: 0.9502
# Epoch 50/50
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.6775 - loss: 0.8521 - val_accuracy: 0.6087 - val_loss: 0.9495

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print("Test Accuracy:", test_accuracy)
# Out:
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6838 - loss: 0.7777
# Test Accuracy: 0.6838065981864929

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
import numpy as np

test_generator.reset()
predictions = model.predict(test_generator)

y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes
# Out:
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true, y_pred)

labels = list(test_generator.class_indices.keys())

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
model.save("emotion_model.keras")
